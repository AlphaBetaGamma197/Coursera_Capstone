# %% [markdown]
# # The Battle of Neighborhoods (Week 2)

# %% [markdown]
# Introduction:
#
#
# This final project explores the best locations for French restaurants throughout the city of New York. As New York is the most diverse city in the world (800 languages are spoken in New York), it has a long tradition of different ethnical restaurants.French restaurants are extremely popular, as they offer a healthy alternative to regular American eating habits. That's why Potentially the create a new French restaurant can have great success and consistent profit. However, as with any business, opening a new restaurant requires serious considerations and is more complicated than it seems from the first glance. In particular, the location of the restaurant is one of the most important factors that will affect whether it will have success or a failure. So our project will attempt to answer the questions “Where should the investor open a French Restaurant?” and “Where should I go If I want great French food?”
#
# Data
# In order to answer the above questions, data on New York City neighborhoods, boroughs to include boundaries, latitude, longitude, restaurants, and restaurant ratings and tips are required.
#
# New York City data containing the neighborhoods and boroughs, latitudes, and longitudes will be obtained from the data source: https://cocl.us/new_york_dataset
#
# All data related to locations and quality of Italian restaurants will be obtained via the FourSquare API utilized via the Request library in Python.
#
# Methodology
# • Data will be collected from https://cocl.us/new_york_dataset and cleaned and processed into a dataframe.
#
# • FourSquare be used to locate all venues and then filtered by Japanese restaurants. Ratings, tips, and likes by users will be counted and added to the dataframe.
#
# • Data will be sorted based on rankings.
#
# • Finally, the data be will be visually assessed using graphing from Python libraries.
#
# Problem Statement
# What is / are the best location(s) for French cuisine in New York City?
# In what Neighborhood and/or borough should the investor open a French restaurant to have the best chance of being successful?
# Where would I go in New York City to have the best French food?

# %% [markdown]
# Analysis
#
# We will import the required libraries for python.
#
# pandas and numpy for handling data.
# request module for using FourSquare API.
# geopy to get co-ordinates of City of New York.
# folium to visualize the results on a map

# %%
#!conda install -c conda-forge folium

# %%
# !conda install -c conda-forge geocoder

# %%
#!conda install -c conda-forge geopy --yes

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
from bs4 import BeautifulSoup

import os

import folium # map rendering library

#import geocoder
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'New York City, NY'

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %%
def get_venues(lat,lng):
    
    #set variables
    radius=5000
    LIMIT=500
    
    CLIENT_ID =  'O4YZ2DJ3PYIIALAU5IUS2XXEB1ZQ424JEDVUZLSUPUBM3OVY'
    CLIENT_SECRET = 'SB5BXJH0SETOXFWKWXHEXMBOHNW5FNCMC1TGEKQPCXE54VXS'
    VERSION = '20210504' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']                                                        
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_venue_details(venue_id):
        
    
    CLIENT_ID =  'O4YZ2DJ3PYIIALAU5IUS2XXEB1ZQ424JEDVUZLSUPUBM3OVY'
    CLIENT_SECRET = 'SB5BXJH0SETOXFWKWXHEXMBOHNW5FNCMC1TGEKQPCXE54VXS'
    VERSION = '20210504' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    data_frame = pd.DataFrame(venue_details,columns=column_names)
    return  data_frame

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

# %%
# get new york data
new_york_data=get_new_york_data()

# %%
new_york_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
new_york_data.shape
# Out:
# (306, 4)

# %%
# prepare neighborhood list that contains italian restaurants
column_names=['Borough', 'Neighborhood', 'ID','Name']
French_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in new_york_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
# ( 280 / 306 ) French Restaurants in Fulton Ferry, Brooklyn:0
# ( 281 / 306 ) French Restaurants in Vinegar Hill, Brooklyn:1
# ( 282 / 306 ) French Restaurants in Weeksville, Brooklyn:0
# ( 283 / 306 ) French Restaurants in Broadway Junction, Brooklyn:1
# ( 284 / 306 ) French Restaurants in Dumbo, Brooklyn:0
# ( 285 / 306 ) French Restaurants in Manor Heights, Staten Island:0
# ( 286 / 306 ) French Restaurants in Willowbrook, Staten Island:0
# ( 287 / 306 ) French Restaurants in Sandy Ground, Staten Island:0
# ( 288 / 306 ) French Restaurants in Egbertville, Staten Island:0
# ( 289 / 306 ) French Restaurants in Roxbury, Queens:1
# ( 290 / 306 ) French Restaurants in Homecrest, Brooklyn:0
# ( 291 / 306 ) French Restaurants in Middle Village, Queens:0
# ( 292 / 306 ) French Restaurants in Prince's Bay, Staten Island:0
# ( 293 / 306 ) French Restaurants in Lighthouse Hill, Staten Island:0
# ( 294 / 306 ) French Restaurants in Richmond Valley, Staten Island:0
# ( 295 / 306 ) French Restaurants in Malba, Queens:0
# ( 296 / 306 ) French Restaurants in Highland Park, Brooklyn:2
# ( 297 / 306 ) French Restaurants in Madison, Brooklyn:0
# ( 298 / 306 ) French Restaurants in Bronxdale, Bronx:0
# ( 299 / 306 ) French Restaurants in Allerton, Bronx:0
# ( 300 / 306 ) French Restaurants in Kingsbridge Heights, Bronx:0
# ( 301 / 306 ) French Restaurants in Erasmus, Brooklyn:1
# ( 302 / 306 ) French Restaurants in Hudson Yards, Manhattan:1
# ( 303 / 306 ) French Restaurants in Hammels, Queens:1
# ( 304 / 306 ) French Restaurants in Bayswater, Queens:0
# ( 305 / 306 ) French Restaurants in Queensbridge, Queens:0
# ( 306 / 306 ) French Restaurants in Fox Hills, Staten Island:0

# %%
French_rest_ny.head()
# Out:
#   Borough  Neighborhood                        ID           Name
# 0   Bronx   City Island  4d7aa83ee540f04d66ba16dc      Bistro SK
# 1   Bronx  High  Bridge  4b80389ff964a520e95d30e3        Yatenga
# 2   Bronx       Melrose  4b80389ff964a520e95d30e3        Yatenga
# 3   Bronx       Melrose  553c1b00498e7eb81316bf1b  Mountain Bird
# 4   Bronx       Melrose  511a937ee88968b8acbba54b  Maison Harlem

# %%
French_rest_ny.shape
# Out:
# (83, 4)

# %% [markdown]
# Let's save these data as the call to retreive them are limited by FOURSQUARE

# %%
French_rest_ny.to_csv('French_rest_ny.csv',index=False)

# %%
French_rest_ny_csv=pd.read_csv('French_rest_ny.csv')

# %%
French_rest_ny_csv.shape
# Out:
# (83, 4)

# %%
French_rest_ny_csv.tail()
# Out:
#       Borough   Neighborhood                        ID                  Name
# 78   Brooklyn  Highland Park  5504c149498e3f73684b13a9        L' Antagoniste
# 79   Brooklyn  Highland Park  439591fcf964a5208c2b1fe3            Chez Oskar
# 80   Brooklyn        Erasmus  4e7d174cb6340a4da75a2cca            Le Paddock
# 81  Manhattan   Hudson Yards  4d0bf7e3f29c236ac675bfe7               Buvette
# 82     Queens        Hammels  4f71ce9de4b0a89fa4b084de  Cuisine By Claudette

# %%
plt.figure(figsize=(8,4), dpi = 100)

# title
plt.title('Number of French Restaurants for each Borough in New York City')

#pie chart
French_rest_ny.groupby('Borough')['ID'].count().plot(kind='pie')

plt.show()

# %%
plt.figure(figsize=(8.5,4.5), dpi = 100)

# title
plt.title('Number of French Restaurants for each Borough in New York City')

#pie chart
French_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(10).plot(kind='pie')

plt.show()

# %%
French_rest_ny[French_rest_ny['Neighborhood']=='East Village']
# Out:
#       Borough  Neighborhood                        ID          Name
# 36  Manhattan  East Village  4d0bf7e3f29c236ac675bfe7       Buvette
# 37  Manhattan  East Village  5db241e86a808900075f6e61  Le Crocodile

# %% [markdown]
# Now we will get the ranking of each restaurant for further analysis.

# %%
# prepare neighborhood list that contains indian resturants
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
French_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1

for row in French_rest_ny.values.tolist():

    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        # we will assign 0 value for these resturants as they may have been 
        #recently opened or details does not exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(French_rest_ny),')','processed')
    French_rest_stats_ny = French_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
French_rest_stats_ny.tail()
# Out:
# {'meta': {'code': 200, 'requestId': '6093e5444332e5492dd46c20'}, 'response': {'venue': {'id': '4d7aa83ee540f04d66ba16dc', 'name': 'Bistro SK', 'contact': {'phone': '7188851670', 'formattedPhone': '(718) 885-1670'}, 'location': {'address': '273 City Island Ave', 'lat': 40.84638676701103, 'lng': -73.78626182722242, 'labeledLatLngs': [{'label': 'display', 'lat': 40.84638676701103, 'lng': -73.78626182722242}, {'label': 'entrance', 'lat': 40.846234, 'lng': -73.786269}], 'postalCode': '10464', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['273 City Island Ave', 'Bronx, NY 10464', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/bistro-sk/4d7aa83ee540f04d66ba16dc', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 7}, 'url': 'http://bistrosk.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 12, 'groups': [{'type': 'others', 'count': 12, 'items': []}], 'summary': '12 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 20, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/bistro-sk/4d7aa83ee540f04d66ba16dc/menu', 'mobileUrl': 'https://foursquare.com/v/4d7aa83ee540f04d66ba16dc/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 19, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 19, 'items': [{'id': '57d35e34498ef8be703ec4f8', 'createdAt': 1473470004, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/81290_9H1Pdp3nUwb5t3BQEWC3F8kg7mKZkJYZRwMi2d8eszo.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'venuePage': {'id': '97766287'}, 'reasons': {'count': 0, 'items': []}, 'page': {'user': {'firstName': 'Bistro SK', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4d7aa83ee540f04d66ba16dc'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1299884094, 'tips': {'count': 7, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 7, 'items': [{'id': '51f50bb5498e3f4d4728a232', 'createdAt': 1375013813, 'text': 'Great service and food in this cozy City Island bistro. Not your typical City Island "glorified diner" menu. Great find.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51f50bb5498e3f4d4728a232', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'BrooklynBoyO', 'countryCode': 'US'}, {'firstName': 'Ericalee', 'lastName': 'G', 'countryCode': 'US'}, {'firstName': 'Chris', 'lastName': 'R', 'countryCode': 'US'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Stephen', 'lastName': 'G', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/ejMbZ8', 'timeZone': 'America/New_York', 'listed': {'count': 10, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 10, 'items': [{'id': '519af3b0498e6e1b3705d215', 'name': 'wc/hv to try', 'description': '', 'type': 'others', 'user': {'firstName': 'Kobie', 'lastName': 'W', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/56807089/list/wchv-to-try', 'canonicalUrl': 'https://foursquare.com/user/56807089/list/wchv-to-try', 'createdAt': 1369109424, 'updatedAt': 1619470960, 'followers': {'count': 2}, 'listItems': {'count': 292, 'items': [{'id': 'v4d7aa83ee540f04d66ba16dc', ...
#                          ID       Name  Likes  Rating  Tips
# 0  4d7aa83ee540f04d66ba16dc  Bistro SK     12     7.5     7
# ( 1 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e544037e9c3dc06c36ab'}, 'response': {'venue': {'id': '4b80389ff964a520e95d30e3', 'name': 'Yatenga', 'contact': {'phone': '2126900699', 'formattedPhone': '(212) 690-0699', 'twitter': 'yatengabistro'}, 'location': {'address': '2269 Adam Clayton Powell Jr Blvd', 'crossStreet': 'btwn 133rd & 134th St.', 'lat': 40.81430599659326, 'lng': -73.94442992027335, 'labeledLatLngs': [{'label': 'display', 'lat': 40.81430599659326, 'lng': -73.94442992027335}], 'postalCode': '10030', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2269 Adam Clayton Powell Jr Blvd (btwn 133rd & 134th St.)', 'New York, NY 10030', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/yatenga/4b80389ff964a520e95d30e3', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 62}, 'url': 'http://yatengabistro.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 104, 'groups': [{'type': 'others', 'count': 104, 'items': []}], 'summary': '104 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 168, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/yatenga/4b80389ff964a520e95d30e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b80389ff964a520e95d30e3/device_menu', 'externalUrl': 'http://yatengabistro.com/menu.php'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 131, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 131, 'items': [{'id': '51743af2498ebf7fd1b1d56d', 'createdAt': 1366571762, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/42079961_l6rcpm7mMbTyGvDO0gSmoFMHGY8EwLQQBNRbxNvmpZQ.jpg', 'width': 1440, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1266694303, 'tips': {'count': 62, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 62, 'items': [{'id': '51f47c40498e369ef408554b', 'createdAt': 1374977088, 'text': 'Mustafa is the most gracious, humble & efficient waiter. Tuna tar tar, tuna nicoise, shrimp app.. Amazing. Service & food is amazing!! A++++!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51f47c40498e369ef408554b', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Tee', 'lastName': 'G', 'countryCode': 'US'}, {'firstName': 'Tiffany', 'lastName': 'K', 'countryCode': 'US'}, {'firstName': 'maciek', 'lastName': 'j', 'countryCode': 'CO'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Nicola', 'lastName': 'M', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/bN0OW5', 'timeZone': 'America/New_York', 'listed': {'count': 167, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 167, 'items': [{'id': '5a834e62f8cbd459a28eb9b0', 'name': '200 Black-Owned Restaurants in NYC', 'description': 'The Foursquare team compiled this list to spotlight some of the best Black-owned restaurants in NYC. Do you want your business to be featured here? Message us at support@foursquare.com.', 'type': 'others', 'user': {'firstName': 'Foursquare City Guide', 'countryCode': 'US', 'type': 'page'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/foursquare/list/200-black ...
#                          ID     Name  Likes  Rating  Tips
# 0  4b80389ff964a520e95d30e3  Yatenga    104     8.5    62
# ( 2 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e545c6ae771ff437a236'}, 'response': {'venue': {'id': '4b80389ff964a520e95d30e3', 'name': 'Yatenga', 'contact': {'phone': '2126900699', 'formattedPhone': '(212) 690-0699', 'twitter': 'yatengabistro'}, 'location': {'address': '2269 Adam Clayton Powell Jr Blvd', 'crossStreet': 'btwn 133rd & 134th St.', 'lat': 40.81430599659326, 'lng': -73.94442992027335, 'labeledLatLngs': [{'label': 'display', 'lat': 40.81430599659326, 'lng': -73.94442992027335}], 'postalCode': '10030', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2269 Adam Clayton Powell Jr Blvd (btwn 133rd & 134th St.)', 'New York, NY 10030', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/yatenga/4b80389ff964a520e95d30e3', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 62}, 'url': 'http://yatengabistro.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 104, 'groups': [{'type': 'others', 'count': 104, 'items': []}], 'summary': '104 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 168, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/yatenga/4b80389ff964a520e95d30e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b80389ff964a520e95d30e3/device_menu', 'externalUrl': 'http://yatengabistro.com/menu.php'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 131, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 131, 'items': [{'id': '51743af2498ebf7fd1b1d56d', 'createdAt': 1366571762, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/42079961_l6rcpm7mMbTyGvDO0gSmoFMHGY8EwLQQBNRbxNvmpZQ.jpg', 'width': 1440, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1266694303, 'tips': {'count': 62, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 62, 'items': [{'id': '51f47c40498e369ef408554b', 'createdAt': 1374977088, 'text': 'Mustafa is the most gracious, humble & efficient waiter. Tuna tar tar, tuna nicoise, shrimp app.. Amazing. Service & food is amazing!! A++++!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51f47c40498e369ef408554b', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Tee', 'lastName': 'G', 'countryCode': 'US'}, {'firstName': 'Tiffany', 'lastName': 'K', 'countryCode': 'US'}, {'firstName': 'maciek', 'lastName': 'j', 'countryCode': 'CO'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Nicola', 'lastName': 'M', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/bN0OW5', 'timeZone': 'America/New_York', 'listed': {'count': 167, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 167, 'items': [{'id': '5a834e62f8cbd459a28eb9b0', 'name': '200 Black-Owned Restaurants in NYC', 'description': 'The Foursquare team compiled this list to spotlight some of the best Black-owned restaurants in NYC. Do you want your business to be featured here? Message us at support@foursquare.com.', 'type': 'others', 'user': {'firstName': 'Foursquare City Guide', 'countryCode': 'US', 'type': 'page'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/foursquare/list/200-black ...
#                          ID     Name  Likes  Rating  Tips
# 0  4b80389ff964a520e95d30e3  Yatenga    104     8.5    62
# ( 3 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e545c53c12399df844bb'}, 'response': {'venue': {'id': '553c1b00498e7eb81316bf1b', 'name': 'Mountain Bird', 'contact': {'phone': '2127444422', 'formattedPhone': '(212) 744-4422'}, 'location': {'address': '2162 2nd Ave', 'lat': 40.793851, 'lng': -73.939942, 'labeledLatLngs': [{'label': 'display', 'lat': 40.793851, 'lng': -73.939942}], 'postalCode': '10029', 'cc': 'US', 'neighborhood': 'East Harlem', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2162 2nd Ave', 'New York, NY 10029', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/mountain-bird/553c1b00498e7eb81316bf1b', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 18}, 'url': 'http://www.mountainbirdnyc.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 80, 'groups': [{'type': 'others', 'count': 80, 'items': []}], 'summary': '80 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 100, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.mountainbirdnyc.com/MBmenu.pdf', 'mobileUrl': 'http://www.mountainbirdnyc.com/MBmenu.pdf', 'externalUrl': 'http://www.mountainbirdnyc.com/MBmenu.pdf'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 39, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 39, 'items': [{'id': '5fe3da3d849f994e7f9b2543', 'createdAt': 1608768061, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2614641_OWI5UReU07XLmsVduRbvapXb-oA6xPRQFju54bJChfM.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1430002432, 'tips': {'count': 18, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 18, 'items': [{'id': '566edf13498e8b6e857fd03b', 'createdAt': 1450106643, 'text': 'Mountain Bird. It’s back. You may not have been aware it left, but that should be a telling sign of how desperately you need me. Tip: Foie gras dumpling consomme? Yeah.', 'type': 'user', 'url': 'http://www.thecoveteur.com/best-hidden-holiday-cocktail-gems-new-york-edition/?utm_source=Twitter&utm_medium=Social%20Media%20&utm_campaign=Best%20Hidden%20Cocktails%20NYC', 'canonicalUrl': 'https://foursquare.com/item/566edf13498e8b6e857fd03b', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Peter', 'lastName': 'S', 'countryCode': 'US'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 5, 'disagreeCount': 0, 'todo': {'count': 8}, 'user': {'firstName': 'Cheap Best Hidden', 'countryCode': 'US', 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/1Gj6yMd', 'timeZone': 'America/New_York', 'listed': {'count': 134, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 134, 'items': [{'id': '5279097411d27cd1954ee4d7', 'name': 'NY places to try', 'description': '', 'type': 'others', 'user': {'firstName': 'Nikki', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/9672463/list/ny-places-to-try', 'canonicalUrl': 'https://foursquare.com/user/9672463/list/ny-places-to-try', 'createdAt': 1383663988, 'updatedAt': 1514308978, 'photo': {'id': '558f9812498e455c15bd775c', 'createdAt': 1435473938, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/38405371_pEVzl_HXbEV--5G0haPgRuKwF5ip9yVL9mUXG4CvXMU.jpg', 'width ...
#                          ID           Name  Likes  Rating  Tips
# 0  553c1b00498e7eb81316bf1b  Mountain Bird     80     8.9    18
# ( 4 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e5458dc547357771afa7'}, 'response': {'venue': {'id': '511a937ee88968b8acbba54b', 'name': 'Maison Harlem', 'contact': {'phone': '2122229224', 'formattedPhone': '(212) 222-9224', 'twitter': 'maisonharlem', 'facebook': '444160015597111', 'facebookUsername': 'MAISONHARLEM', 'facebookName': 'Maison Harlem'}, 'location': {'address': '341 Saint Nicholas Ave', 'lat': 40.8121095912697, 'lng': -73.95172150373327, 'labeledLatLngs': [{'label': 'display', 'lat': 40.8121095912697, 'lng': -73.95172150373327}], 'postalCode': '10027', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['341 Saint Nicholas Ave', 'New York, NY 10027', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/maison-harlem/511a937ee88968b8acbba54b', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 88}, 'url': 'http://www.maisonharlem.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 289, 'groups': [{'type': 'others', 'count': 289, 'items': []}], 'summary': '289 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 403, 'delivery': {'id': '281540', 'url': 'https://www.seamless.com/menu/maison-harlem-341-st-nicholas-ave-new-york/281540?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=281540', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/maison-harlem/511a937ee88968b8acbba54b/menu', 'mobileUrl': 'https://foursquare.com/v/511a937ee88968b8acbba54b/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 287, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 287, 'items': [{'id': '51563970e4b037129d4a3989', 'createdAt': 1364605296, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/51957643_JZBl5z2e02JbX2mEvK6sUiWG8_m-5zfWe69ODHEFstw.jpg', 'width': 960, 'height': 720, 'visibility': 'public'}]}]}, 'venuePage': {'id': '48113581'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': '"We are two food and wine loving French New Yorkers who are bringing an exciting restaurant to Harlem, one of the most beautiful neighborhoods in the borough."', 'storeId': '', 'page': {'user': {'firstName': 'Maison Harlem', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '511a937ee88968b8acbba54b'}, 'tips': {'count': 8}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1360696190, 'tips': {'count': 88, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 88, 'items': [{'id': '51adff1f498e9d4401217623', 'createdAt': 1370357535, 'text': 'A classy neighborhood joint with a good bar and great classic French bistro fare. The hefty grilled burger is worth a try as well.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51adff1f498e9d4401217623', 'lang': 'en', 'likes': {'count': 16, 'groups': [{'type': 'others', 'count': 16, 'items': []}], 'summary': '16 likes'}, 'logView': True, 'agreeCount': 16, 'disagreeCount': 0, 'todo': {'count': 10}, 'user': {'firstName': 'Serious Eats', 'countryCode': 'US', 'type': 'page'}}]}]}, 'short ...
#                          ID           Name  Likes  Rating  Tips
# 0  511a937ee88968b8acbba54b  Maison Harlem    289     8.6    88
# ( 5 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e545702fd35e2251ab47'}, 'response': {'venue': {'id': '553c1b00498e7eb81316bf1b', 'name': 'Mountain Bird', 'contact': {'phone': '2127444422', 'formattedPhone': '(212) 744-4422'}, 'location': {'address': '2162 2nd Ave', 'lat': 40.793851, 'lng': -73.939942, 'labeledLatLngs': [{'label': 'display', 'lat': 40.793851, 'lng': -73.939942}], 'postalCode': '10029', 'cc': 'US', 'neighborhood': 'East Harlem', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2162 2nd Ave', 'New York, NY 10029', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/mountain-bird/553c1b00498e7eb81316bf1b', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 18}, 'url': 'http://www.mountainbirdnyc.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 80, 'groups': [{'type': 'others', 'count': 80, 'items': []}], 'summary': '80 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 100, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.mountainbirdnyc.com/MBmenu.pdf', 'mobileUrl': 'http://www.mountainbirdnyc.com/MBmenu.pdf', 'externalUrl': 'http://www.mountainbirdnyc.com/MBmenu.pdf'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 39, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 39, 'items': [{'id': '5fe3da3d849f994e7f9b2543', 'createdAt': 1608768061, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2614641_OWI5UReU07XLmsVduRbvapXb-oA6xPRQFju54bJChfM.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1430002432, 'tips': {'count': 18, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 18, 'items': [{'id': '566edf13498e8b6e857fd03b', 'createdAt': 1450106643, 'text': 'Mountain Bird. It’s back. You may not have been aware it left, but that should be a telling sign of how desperately you need me. Tip: Foie gras dumpling consomme? Yeah.', 'type': 'user', 'url': 'http://www.thecoveteur.com/best-hidden-holiday-cocktail-gems-new-york-edition/?utm_source=Twitter&utm_medium=Social%20Media%20&utm_campaign=Best%20Hidden%20Cocktails%20NYC', 'canonicalUrl': 'https://foursquare.com/item/566edf13498e8b6e857fd03b', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Peter', 'lastName': 'S', 'countryCode': 'US'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 5, 'disagreeCount': 0, 'todo': {'count': 8}, 'user': {'firstName': 'Cheap Best Hidden', 'countryCode': 'US', 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/1Gj6yMd', 'timeZone': 'America/New_York', 'listed': {'count': 134, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 134, 'items': [{'id': '5279097411d27cd1954ee4d7', 'name': 'NY places to try', 'description': '', 'type': 'others', 'user': {'firstName': 'Nikki', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/9672463/list/ny-places-to-try', 'canonicalUrl': 'https://foursquare.com/user/9672463/list/ny-places-to-try', 'createdAt': 1383663988, 'updatedAt': 1514308978, 'photo': {'id': '558f9812498e455c15bd775c', 'createdAt': 1435473938, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/38405371_pEVzl_HXbEV--5G0haPgRuKwF5ip9yVL9mUXG4CvXMU.jpg', 'width ...
#                          ID           Name  Likes  Rating  Tips
# 0  553c1b00498e7eb81316bf1b  Mountain Bird     80     8.9    18
# ( 6 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e54652ab013cfd97bdf5'}, 'response': {'venue': {'id': '553c1b00498e7eb81316bf1b', 'name': 'Mountain Bird', 'contact': {'phone': '2127444422', 'formattedPhone': '(212) 744-4422'}, 'location': {'address': '2162 2nd Ave', 'lat': 40.793851, 'lng': -73.939942, 'labeledLatLngs': [{'label': 'display', 'lat': 40.793851, 'lng': -73.939942}], 'postalCode': '10029', 'cc': 'US', 'neighborhood': 'East Harlem', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2162 2nd Ave', 'New York, NY 10029', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/mountain-bird/553c1b00498e7eb81316bf1b', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 18}, 'url': 'http://www.mountainbirdnyc.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 80, 'groups': [{'type': 'others', 'count': 80, 'items': []}], 'summary': '80 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 100, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.mountainbirdnyc.com/MBmenu.pdf', 'mobileUrl': 'http://www.mountainbirdnyc.com/MBmenu.pdf', 'externalUrl': 'http://www.mountainbirdnyc.com/MBmenu.pdf'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 39, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 39, 'items': [{'id': '5fe3da3d849f994e7f9b2543', 'createdAt': 1608768061, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2614641_OWI5UReU07XLmsVduRbvapXb-oA6xPRQFju54bJChfM.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1430002432, 'tips': {'count': 18, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 18, 'items': [{'id': '566edf13498e8b6e857fd03b', 'createdAt': 1450106643, 'text': 'Mountain Bird. It’s back. You may not have been aware it left, but that should be a telling sign of how desperately you need me. Tip: Foie gras dumpling consomme? Yeah.', 'type': 'user', 'url': 'http://www.thecoveteur.com/best-hidden-holiday-cocktail-gems-new-york-edition/?utm_source=Twitter&utm_medium=Social%20Media%20&utm_campaign=Best%20Hidden%20Cocktails%20NYC', 'canonicalUrl': 'https://foursquare.com/item/566edf13498e8b6e857fd03b', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Peter', 'lastName': 'S', 'countryCode': 'US'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 5, 'disagreeCount': 0, 'todo': {'count': 8}, 'user': {'firstName': 'Cheap Best Hidden', 'countryCode': 'US', 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/1Gj6yMd', 'timeZone': 'America/New_York', 'listed': {'count': 134, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 134, 'items': [{'id': '5279097411d27cd1954ee4d7', 'name': 'NY places to try', 'description': '', 'type': 'others', 'user': {'firstName': 'Nikki', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/9672463/list/ny-places-to-try', 'canonicalUrl': 'https://foursquare.com/user/9672463/list/ny-places-to-try', 'createdAt': 1383663988, 'updatedAt': 1514308978, 'photo': {'id': '558f9812498e455c15bd775c', 'createdAt': 1435473938, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/38405371_pEVzl_HXbEV--5G0haPgRuKwF5ip9yVL9mUXG4CvXMU.jpg', 'width ...
#                          ID           Name  Likes  Rating  Tips
# 0  553c1b00498e7eb81316bf1b  Mountain Bird     80     8.9    18
# ( 7 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e54630ee1636601b4f1f'}, 'response': {'venue': {'id': '4b80389ff964a520e95d30e3', 'name': 'Yatenga', 'contact': {'phone': '2126900699', 'formattedPhone': '(212) 690-0699', 'twitter': 'yatengabistro'}, 'location': {'address': '2269 Adam Clayton Powell Jr Blvd', 'crossStreet': 'btwn 133rd & 134th St.', 'lat': 40.81430599659326, 'lng': -73.94442992027335, 'labeledLatLngs': [{'label': 'display', 'lat': 40.81430599659326, 'lng': -73.94442992027335}], 'postalCode': '10030', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2269 Adam Clayton Powell Jr Blvd (btwn 133rd & 134th St.)', 'New York, NY 10030', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/yatenga/4b80389ff964a520e95d30e3', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 62}, 'url': 'http://yatengabistro.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 104, 'groups': [{'type': 'others', 'count': 104, 'items': []}], 'summary': '104 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 168, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/yatenga/4b80389ff964a520e95d30e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b80389ff964a520e95d30e3/device_menu', 'externalUrl': 'http://yatengabistro.com/menu.php'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 131, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 131, 'items': [{'id': '51743af2498ebf7fd1b1d56d', 'createdAt': 1366571762, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/42079961_l6rcpm7mMbTyGvDO0gSmoFMHGY8EwLQQBNRbxNvmpZQ.jpg', 'width': 1440, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1266694303, 'tips': {'count': 62, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 62, 'items': [{'id': '51f47c40498e369ef408554b', 'createdAt': 1374977088, 'text': 'Mustafa is the most gracious, humble & efficient waiter. Tuna tar tar, tuna nicoise, shrimp app.. Amazing. Service & food is amazing!! A++++!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51f47c40498e369ef408554b', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Tee', 'lastName': 'G', 'countryCode': 'US'}, {'firstName': 'Tiffany', 'lastName': 'K', 'countryCode': 'US'}, {'firstName': 'maciek', 'lastName': 'j', 'countryCode': 'CO'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Nicola', 'lastName': 'M', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/bN0OW5', 'timeZone': 'America/New_York', 'listed': {'count': 167, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 167, 'items': [{'id': '5a834e62f8cbd459a28eb9b0', 'name': '200 Black-Owned Restaurants in NYC', 'description': 'The Foursquare team compiled this list to spotlight some of the best Black-owned restaurants in NYC. Do you want your business to be featured here? Message us at support@foursquare.com.', 'type': 'others', 'user': {'firstName': 'Foursquare City Guide', 'countryCode': 'US', 'type': 'page'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/foursquare/list/200-black ...
#                          ID     Name  Likes  Rating  Tips
# 0  4b80389ff964a520e95d30e3  Yatenga    104     8.5    62
# ( 8 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e5464332e5492dd47095'}, 'response': {'venue': {'id': '553c1b00498e7eb81316bf1b', 'name': 'Mountain Bird', 'contact': {'phone': '2127444422', 'formattedPhone': '(212) 744-4422'}, 'location': {'address': '2162 2nd Ave', 'lat': 40.793851, 'lng': -73.939942, 'labeledLatLngs': [{'label': 'display', 'lat': 40.793851, 'lng': -73.939942}], 'postalCode': '10029', 'cc': 'US', 'neighborhood': 'East Harlem', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2162 2nd Ave', 'New York, NY 10029', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/mountain-bird/553c1b00498e7eb81316bf1b', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 18}, 'url': 'http://www.mountainbirdnyc.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 80, 'groups': [{'type': 'others', 'count': 80, 'items': []}], 'summary': '80 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 100, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.mountainbirdnyc.com/MBmenu.pdf', 'mobileUrl': 'http://www.mountainbirdnyc.com/MBmenu.pdf', 'externalUrl': 'http://www.mountainbirdnyc.com/MBmenu.pdf'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 39, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 39, 'items': [{'id': '5fe3da3d849f994e7f9b2543', 'createdAt': 1608768061, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2614641_OWI5UReU07XLmsVduRbvapXb-oA6xPRQFju54bJChfM.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1430002432, 'tips': {'count': 18, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 18, 'items': [{'id': '566edf13498e8b6e857fd03b', 'createdAt': 1450106643, 'text': 'Mountain Bird. It’s back. You may not have been aware it left, but that should be a telling sign of how desperately you need me. Tip: Foie gras dumpling consomme? Yeah.', 'type': 'user', 'url': 'http://www.thecoveteur.com/best-hidden-holiday-cocktail-gems-new-york-edition/?utm_source=Twitter&utm_medium=Social%20Media%20&utm_campaign=Best%20Hidden%20Cocktails%20NYC', 'canonicalUrl': 'https://foursquare.com/item/566edf13498e8b6e857fd03b', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Peter', 'lastName': 'S', 'countryCode': 'US'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 5, 'disagreeCount': 0, 'todo': {'count': 8}, 'user': {'firstName': 'Cheap Best Hidden', 'countryCode': 'US', 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/1Gj6yMd', 'timeZone': 'America/New_York', 'listed': {'count': 134, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 134, 'items': [{'id': '5279097411d27cd1954ee4d7', 'name': 'NY places to try', 'description': '', 'type': 'others', 'user': {'firstName': 'Nikki', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/9672463/list/ny-places-to-try', 'canonicalUrl': 'https://foursquare.com/user/9672463/list/ny-places-to-try', 'createdAt': 1383663988, 'updatedAt': 1514308978, 'photo': {'id': '558f9812498e455c15bd775c', 'createdAt': 1435473938, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/38405371_pEVzl_HXbEV--5G0haPgRuKwF5ip9yVL9mUXG4CvXMU.jpg', 'width ...
#                          ID           Name  Likes  Rating  Tips
# 0  553c1b00498e7eb81316bf1b  Mountain Bird     80     8.9    18
# ( 9 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e5474332e5492dd47149'}, 'response': {'venue': {'id': '4b80389ff964a520e95d30e3', 'name': 'Yatenga', 'contact': {'phone': '2126900699', 'formattedPhone': '(212) 690-0699', 'twitter': 'yatengabistro'}, 'location': {'address': '2269 Adam Clayton Powell Jr Blvd', 'crossStreet': 'btwn 133rd & 134th St.', 'lat': 40.81430599659326, 'lng': -73.94442992027335, 'labeledLatLngs': [{'label': 'display', 'lat': 40.81430599659326, 'lng': -73.94442992027335}], 'postalCode': '10030', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2269 Adam Clayton Powell Jr Blvd (btwn 133rd & 134th St.)', 'New York, NY 10030', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/yatenga/4b80389ff964a520e95d30e3', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 62}, 'url': 'http://yatengabistro.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 104, 'groups': [{'type': 'others', 'count': 104, 'items': []}], 'summary': '104 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 168, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/yatenga/4b80389ff964a520e95d30e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b80389ff964a520e95d30e3/device_menu', 'externalUrl': 'http://yatengabistro.com/menu.php'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 131, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 131, 'items': [{'id': '51743af2498ebf7fd1b1d56d', 'createdAt': 1366571762, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/42079961_l6rcpm7mMbTyGvDO0gSmoFMHGY8EwLQQBNRbxNvmpZQ.jpg', 'width': 1440, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1266694303, 'tips': {'count': 62, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 62, 'items': [{'id': '51f47c40498e369ef408554b', 'createdAt': 1374977088, 'text': 'Mustafa is the most gracious, humble & efficient waiter. Tuna tar tar, tuna nicoise, shrimp app.. Amazing. Service & food is amazing!! A++++!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51f47c40498e369ef408554b', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Tee', 'lastName': 'G', 'countryCode': 'US'}, {'firstName': 'Tiffany', 'lastName': 'K', 'countryCode': 'US'}, {'firstName': 'maciek', 'lastName': 'j', 'countryCode': 'CO'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Nicola', 'lastName': 'M', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/bN0OW5', 'timeZone': 'America/New_York', 'listed': {'count': 167, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 167, 'items': [{'id': '5a834e62f8cbd459a28eb9b0', 'name': '200 Black-Owned Restaurants in NYC', 'description': 'The Foursquare team compiled this list to spotlight some of the best Black-owned restaurants in NYC. Do you want your business to be featured here? Message us at support@foursquare.com.', 'type': 'others', 'user': {'firstName': 'Foursquare City Guide', 'countryCode': 'US', 'type': 'page'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/foursquare/list/200-black ...
#                          ID     Name  Likes  Rating  Tips
# 0  4b80389ff964a520e95d30e3  Yatenga    104     8.5    62
# ( 10 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e547abb8ae22615b67bd'}, 'response': {'venue': {'id': '4e7d174cb6340a4da75a2cca', 'name': 'Le Paddock', 'contact': {'phone': '7184350921', 'formattedPhone': '(718) 435-0921', 'twitter': 'lepaddockbk'}, 'location': {'address': '1235 Prospect Ave', 'crossStreet': 'at Reeve Pl.', 'lat': 40.652872710523795, 'lng': -73.97605651846555, 'labeledLatLngs': [{'label': 'display', 'lat': 40.652872710523795, 'lng': -73.97605651846555}], 'postalCode': '11218', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1235 Prospect Ave (at Reeve Pl.)', 'Brooklyn, NY 11218', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/le-paddock/4e7d174cb6340a4da75a2cca', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d123941735', 'name': 'Wine Bar', 'pluralName': 'Wine Bars', 'shortName': 'Wine Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 56}, 'url': 'http://www.lepaddockbrooklyn.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 141, 'groups': [{'type': 'others', 'count': 141, 'items': []}], 'summary': '141 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 190, 'delivery': {'id': '360743', 'url': 'https://www.seamless.com/menu/le-paddock-1235-prospect-ave-brooklyn/360743?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=360743', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/le-paddock/4e7d174cb6340a4da75a2cca/menu', 'mobileUrl': 'https://foursquare.com/v/4e7d174cb6340a4da75a2cca/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 138, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 138, 'items': [{'id': '4fc10b08e4b0758d916acff5', 'createdAt': 1338051336, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/LebOroGguziRACZT0Fb5vs6-zItAUDu0NDK6QeEpLWY.jpg', 'width': 720, 'height': 540, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'A cozy neighborhood wine bar also offering weekend brunch.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1316820812, 'tips': {'count': 56, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 56, 'items': [{'id': '51e89149498ea394072421b0', 'createdAt': 1374196041, 'text': 'New Lemon-Pear Martini (made with Soju) is light and refreshing.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51e89149498ea394072421b0', 'lang': 'en', 'likes': {'count': 6, 'groups': [{'type': 'others', 'count': 6, 'items': [{'firstName': 'Remco', 'lastName': 'G', 'countryCode': 'NL'}, {'firstName': 'AyPee - Arthur', 'lastName': 'P', 'countryCode': 'GB'}, {'firstName': 'T. Scott', 'lastName': 'C', 'countryCode': 'US'}, {'firstName': 'Jeffrey', 'lastName': 'G', 'countryCode': 'US'}]}], 'summary': '6 likes'}, 'logView': True, 'agreeCount': 6, 'di ...
#                          ID        Name  Likes  Rating  Tips
# 0  4e7d174cb6340a4da75a2cca  Le Paddock    141     8.9    56
# ( 11 / 83 ) processed
# ...
#                          ID        Name  Likes  Rating  Tips
# 0  439591fcf964a5208c2b1fe3  Chez Oskar    201     8.3    97
# ( 80 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e55b4eeac90fe508e134'}, 'response': {'venue': {'id': '4e7d174cb6340a4da75a2cca', 'name': 'Le Paddock', 'contact': {'phone': '7184350921', 'formattedPhone': '(718) 435-0921', 'twitter': 'lepaddockbk'}, 'location': {'address': '1235 Prospect Ave', 'crossStreet': 'at Reeve Pl.', 'lat': 40.652872710523795, 'lng': -73.97605651846555, 'labeledLatLngs': [{'label': 'display', 'lat': 40.652872710523795, 'lng': -73.97605651846555}], 'postalCode': '11218', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1235 Prospect Ave (at Reeve Pl.)', 'Brooklyn, NY 11218', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/le-paddock/4e7d174cb6340a4da75a2cca', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d123941735', 'name': 'Wine Bar', 'pluralName': 'Wine Bars', 'shortName': 'Wine Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 56}, 'url': 'http://www.lepaddockbrooklyn.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 141, 'groups': [{'type': 'others', 'count': 141, 'items': []}], 'summary': '141 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 190, 'delivery': {'id': '360743', 'url': 'https://www.seamless.com/menu/le-paddock-1235-prospect-ave-brooklyn/360743?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=360743', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/le-paddock/4e7d174cb6340a4da75a2cca/menu', 'mobileUrl': 'https://foursquare.com/v/4e7d174cb6340a4da75a2cca/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 138, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 138, 'items': [{'id': '4fc10b08e4b0758d916acff5', 'createdAt': 1338051336, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/LebOroGguziRACZT0Fb5vs6-zItAUDu0NDK6QeEpLWY.jpg', 'width': 720, 'height': 540, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'A cozy neighborhood wine bar also offering weekend brunch.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1316820812, 'tips': {'count': 56, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 56, 'items': [{'id': '51e89149498ea394072421b0', 'createdAt': 1374196041, 'text': 'New Lemon-Pear Martini (made with Soju) is light and refreshing.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51e89149498ea394072421b0', 'lang': 'en', 'likes': {'count': 6, 'groups': [{'type': 'others', 'count': 6, 'items': [{'firstName': 'Remco', 'lastName': 'G', 'countryCode': 'NL'}, {'firstName': 'AyPee - Arthur', 'lastName': 'P', 'countryCode': 'GB'}, {'firstName': 'T. Scott', 'lastName': 'C', 'countryCode': 'US'}, {'firstName': 'Jeffrey', 'lastName': 'G', 'countryCode': 'US'}]}], 'summary': '6 likes'}, 'logView': True, 'agreeCount': 6, 'di ...
#                          ID        Name  Likes  Rating  Tips
# 0  4e7d174cb6340a4da75a2cca  Le Paddock    141     8.9    56
# ( 81 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e55b9a63455268f772d9'}, 'response': {'venue': {'id': '4d0bf7e3f29c236ac675bfe7', 'name': 'Buvette', 'contact': {'phone': '2122553590', 'formattedPhone': '(212) 255-3590', 'twitter': 'ilovebuvette', 'instagram': 'buvettenyc', 'facebook': '129367513800158', 'facebookName': 'Buvette'}, 'location': {'address': '42 Grove St', 'crossStreet': 'btwn Bedford & Bleecker St', 'lat': 40.732782202032624, 'lng': -74.00427521034509, 'labeledLatLngs': [{'label': 'display', 'lat': 40.732782202032624, 'lng': -74.00427521034509}, {'label': 'entrance', 'lat': 40.732721, 'lng': -74.004348}], 'postalCode': '10014', 'cc': 'US', 'neighborhood': 'West Village', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['42 Grove St (btwn Bedford & Bleecker St)', 'New York, NY 10014', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/buvette/4d0bf7e3f29c236ac675bfe7', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d143941735', 'name': 'Breakfast Spot', 'pluralName': 'Breakfast Spots', 'shortName': 'Breakfast', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 527}, 'url': 'http://www.ilovebuvette.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 1864, 'groups': [{'type': 'others', 'count': 1864, 'items': []}], 'summary': '1864 Likes'}, 'dislike': False, 'ok': False, 'rating': 9.3, 'ratingColor': '00B551', 'ratingSignals': 2397, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/buvette/4d0bf7e3f29c236ac675bfe7/menu', 'mobileUrl': 'https://foursquare.com/v/4d0bf7e3f29c236ac675bfe7/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 1689, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 1689, 'items': [{'id': '51f0344e454a356fe0669dbf', 'createdAt': 1374696526, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/60624226_V2GxpKemkIhJHrW1JVGDXXvKK8ZGIfUO6TTQWCBXLL8.jpg', 'width': 1600, 'height': 1068, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1292629987, 'tips': {'count': 527, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 527, 'items': [{'id': '4e367b53aeb7f67fbd3b6349', 'createdAt': 1312193363, 'text': 'French-leaning small plates can be cobbled together to compose an excellent & affordable meal here. Try the classic croque madame ($10) or the\xa0brandade\xa0($9), a pot of featherlight whipped salt cod.', 'type': 'user', 'url': 'http://tmout.us/pAfHZs', 'canonicalUrl': 'https://foursquare.com/item/4e367b53aeb7f67fbd3b6349', 'lang': 'en', 'likes': {'count': 18, 'groups': [{'type': 'others', 'count': 18, 'items': []}], 'summary': '18 likes'}, 'logView': True, 'agreeCount': 18, 'disagreeCount': 0, 'todo': {'count': 84}, 'user': {'firstName': 'Time Out New York', 'countryCode': 'US', 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/fXzEID', 'timeZone': 'America/New_York', 'listed': {'count': 6051, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 6051, 'items': [{'id': '4ddef6d11fc79ef4589b5dc3', 'name': 'NYC Brunch', 'description': 'Warning: waits may be long.  If looking for a reservations, just go to Five Points or Locanda Verde.', 'type': 'others', 'user': {'firstName': 'Noah', 'lastName': 'W', 'address': '', ...
#                          ID     Name  Likes  Rating  Tips
# 0  4d0bf7e3f29c236ac675bfe7  Buvette   1864     9.3   527
# ( 82 / 83 ) processed
# {'meta': {'code': 200, 'requestId': '6093e55c30ee1636601b7e21'}, 'response': {'venue': {'id': '4f71ce9de4b0a89fa4b084de', 'name': 'Cuisine By Claudette', 'contact': {'phone': '7189455511', 'formattedPhone': '(718) 945-5511'}, 'location': {'address': '143 Beach 116th St', 'lat': 40.57886817253805, 'lng': -73.83686820073987, 'labeledLatLngs': [{'label': 'display', 'lat': 40.57886817253805, 'lng': -73.83686820073987}, {'label': 'entrance', 'lat': 40.578836, 'lng': -73.836833}], 'postalCode': '11694', 'cc': 'US', 'neighborhood': 'Rockaway Beach', 'city': 'Rockaway Park', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['143 Beach 116th St', 'Rockaway Park, NY 11694', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/cuisine-by-claudette/4f71ce9de4b0a89fa4b084de', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 9}, 'price': {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 24, 'groups': [{'type': 'others', 'count': 24, 'items': []}], 'summary': '24 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 33, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/cuisine-by-claudette/4f71ce9de4b0a89fa4b084de/menu', 'mobileUrl': 'https://foursquare.com/v/4f71ce9de4b0a89fa4b084de/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 57, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 57, 'items': [{'id': '54132fb7498e16dbbeb34833', 'createdAt': 1410543543, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/27455557_BhlBxmt2_wU-fG1AJD92z5yTe7JJqtEBC0P2wxARexA.jpg', 'width': 640, 'height': 640, 'visibility': 'public'}]}]}, 'venuePage': {'id': '94604626'}, 'reasons': {'count': 0, 'items': []}, 'description': 'Fresh Bakery, Pastries.  The best chicken dishes, pulled pork buns, imported espresso, & cookie creations! Cute one-stop for gourmet everything.', 'page': {'user': {'firstName': 'Cuisine By Claudette', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4f71ce9de4b0a89fa4b084de'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1332858525, 'tips': {'count': 9, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 9, 'items': [{'id': '553579d7498e0372fc2b8ade', 'createdAt': 1429567959, 'text': 'A delightful enclave in the rockaways. Carrot cake was amazing and nice tea. Great service by kind folks.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/553579d7498e0372fc2b8ade', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': []}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Loren', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/GWEBep', 'timeZone': 'America/New_York', 'listed': {'count': 32, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 32, 'items': [{'id': ...
#                          ID                  Name  Likes  Rating  Tips
# 0  4f71ce9de4b0a89fa4b084de  Cuisine By Claudette     24     8.5     9
# ( 83 / 83 ) processed
#       Borough   Neighborhood                        ID                  Name  \
# 78   Brooklyn  Highland Park  5504c149498e3f73684b13a9        L' Antagoniste
# 79   Brooklyn  Highland Park  439591fcf964a5208c2b1fe3            Chez Oskar
# 80   Brooklyn        Erasmus  4e7d174cb6340a4da75a2cca            Le Paddock
# 81  Manhattan   Hudson Yards  4d0bf7e3f29c236ac675bfe7               Buvette
# 82     Queens        Hammels  4f71ce9de4b0a89fa4b084de  Cuisine By Claudette
#
#    Likes  Rating Tips
# 78    87     8.5   28
# 79   201     8.3   97
# 80   141     8.9   56
# 81  1864     9.3  527
# 82    24     8.5    9

# %%
print('Shape of French restaurant static by Neighborhood :',French_rest_stats_ny.shape,'Versus shape of the actual number of French restaurant :',French_rest_ny.shape)
# Out:
# Shape of French restaurant static by Neighborhood : (83, 7) Versus shape of the actual number of French restaurant : (83, 4)

# %% [markdown]
# Now that we've obtain data for all French restaurants in New York and as the numbre of calls to get details for venue are premium call and have limit of 500 per month, as done earlier lets save those datas to a csv file that we'll use for the rest of our study

# %%
French_rest_stats_ny.to_csv('French_rest_stats_ny.csv',index=False)

# %%
French_rest_stats_ny_csv=pd.read_csv('French_rest_stats_ny.csv')

# %%
French_rest_stats_ny_csv.shape
# Out:
# (83, 7)

# %%
French_rest_stats_ny_csv.head()
# Out:
#   Borough  Neighborhood                        ID           Name  Likes  \
# 0   Bronx   City Island  4d7aa83ee540f04d66ba16dc      Bistro SK     12
# 1   Bronx  High  Bridge  4b80389ff964a520e95d30e3        Yatenga    104
# 2   Bronx       Melrose  4b80389ff964a520e95d30e3        Yatenga    104
# 3   Bronx       Melrose  553c1b00498e7eb81316bf1b  Mountain Bird     80
# 4   Bronx       Melrose  511a937ee88968b8acbba54b  Maison Harlem    289
#
#    Rating  Tips
# 0     7.5     7
# 1     8.5    62
# 2     8.5    62
# 3     8.9    18
# 4     8.6    88

# %%
French_rest_stats_ny_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       83 non-null     object
#  1   Neighborhood  83 non-null     object
#  2   ID            83 non-null     object
#  3   Name          83 non-null     object
#  4   Likes         83 non-null     int64
#  5   Rating        83 non-null     float64
#  6   Tips          83 non-null     int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 4.7+ KB

# %% [markdown]
# It appear that Likes and Tips are string values. We would need to convert them into float for further analysis

# %%
French_rest_stats_ny_csv['Likes']=French_rest_stats_ny_csv['Likes'].astype('float64')
French_rest_stats_ny_csv['Tips']=French_rest_stats_ny_csv['Tips'].astype('float64')
French_rest_stats_ny_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       83 non-null     object
#  1   Neighborhood  83 non-null     object
#  2   ID            83 non-null     object
#  3   Name          83 non-null     object
#  4   Likes         83 non-null     float64
#  5   Rating        83 non-null     float64
#  6   Tips          83 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 4.7+ KB

# %% [markdown]
# # Restaurant with maximum Likes

# %%
French_rest_stats_ny_csv.iloc[French_rest_stats_ny_csv['Likes'].idxmax]
# Out:
# Borough                        Manhattan
# Neighborhood                   Chinatown
# ID              4d0bf7e3f29c236ac675bfe7
# Name                             Buvette
# Likes                               1864
# Rating                               9.3
# Tips                                 527
# Name: 25, dtype: object

# %% [markdown]
# # Restaurant with maximum Rating

# %%
French_rest_stats_ny_csv.iloc[French_rest_stats_ny_csv['Rating'].idxmax]
# Out:
# Borough                         Brooklyn
# Neighborhood                  Greenpoint
# ID              5db241e86a808900075f6e61
# Name                        Le Crocodile
# Likes                                 59
# Rating                               9.4
# Tips                                  12
# Name: 11, dtype: object

# %% [markdown]
# # Restaurant with maximum Tips

# %%
French_rest_stats_ny_csv.iloc[French_rest_stats_ny_csv['Tips'].idxmax]
# Out:
# Borough                        Manhattan
# Neighborhood                   Chinatown
# ID              4d0bf7e3f29c236ac675bfe7
# Name                             Buvette
# Likes                               1864
# Rating                               9.3
# Tips                                 527
# Name: 25, dtype: object

# %% [markdown]
# Let check in which neighborhood French restaurent are the better rated

# %%
ny_neighborhood_stats=French_rest_stats_ny_csv.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']


ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#          Neighborhood  Average Rating
# 40   Long Island City             9.4
# 52         North Side             9.4
# 22  East Williamsburg             9.4
# 63         South Side             9.4
# 64    Stuyvesant Town             9.4
# 65          Sunnyside             9.4
# 35      Hunters Point             9.4
# 42    Lower East Side             9.4
# 69       Vinegar Hill             9.4
# 28         Greenpoint             9.4

# %% [markdown]
# What if we illustrate the average rating at the Borough Level

# %%
ny_borhood_stats=French_rest_stats_ny_csv.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borhood_stats.columns=['Borough','Average Rating']


ny_borhood_stats.sort_values(['Average Rating'],ascending=False)
# Out:
#          Borough  Average Rating
# 2      Manhattan        9.228571
# 1       Brooklyn        8.860000
# 3         Queens        8.750000
# 0          Bronx        8.566667
# 4  Staten Island        7.300000

# %% [markdown]
# It appear that Manhattan have the better French restaurants

# %%
ny_neighborhood_stats=pd.merge(ny_neighborhood_stats,new_york_data, on='Neighborhood')
ny_neighborhood_stats=ny_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Average Rating']]

ny_neighborhood_stats
# Out:
#           Borough         Neighborhood   Latitude  Longitude  Average Rating
# 0          Queens              Arverne  40.589144 -73.791992        8.500000
# 1       Manhattan    Battery Park City  40.711932 -74.016869        9.300000
# 2          Queens         Belle Harbor  40.576156 -73.854018        8.500000
# 3          Queens           Blissville  40.737251 -73.932442        9.400000
# 4        Brooklyn         Borough Park  40.633131 -73.990498        8.900000
# 5          Queens        Broad Channel  40.603027 -73.820055        8.500000
# 6        Brooklyn    Broadway Junction  40.677861 -73.903317        8.500000
# 7        Brooklyn          Brownsville  40.663950 -73.910235        8.550000
# 8   Staten Island           Bulls Head  40.609592 -74.159409        7.300000
# 9        Brooklyn             Bushwick  40.698116 -73.925258        9.000000
# 10      Manhattan        Carnegie Hill  40.782683 -73.953256        9.100000
# 11      Manhattan       Central Harlem  40.815976 -73.943211        8.900000
# 12      Manhattan              Chelsea  40.744035 -74.003116        8.300000
# 13  Staten Island              Chelsea  40.594726 -74.189560        8.300000
# 14      Manhattan            Chinatown  40.715618 -73.994279        9.300000
# 15          Bronx          City Island  40.847247 -73.786488        7.500000
# 16      Manhattan         Civic Center  40.715229 -74.005415        9.300000
# 17      Manhattan              Clinton  40.759101 -73.996119        9.300000
# 18          Bronx    Concourse Village  40.824780 -73.915847        8.550000
# 19       Brooklyn          Ditmas Park  40.643675 -73.961013        8.900000
# 20         Queens           Douglaston  40.766846 -73.742498        8.400000
# 21       Brooklyn        East Flatbush  40.641718 -73.936103        8.900000
# 22      Manhattan         East Village  40.727847 -73.982226        9.350000
# 23       Brooklyn    East Williamsburg  40.708492 -73.938858        9.400000
# 24       Brooklyn              Erasmus  40.646926 -73.948177        8.900000
# 25      Manhattan   Financial District  40.707107 -74.010665        9.300000
# 26       Brooklyn             Flatbush  40.636326 -73.958401        8.900000
# 27      Manhattan             Flatiron  40.739673 -73.990947        9.300000
# 28      Manhattan             Gramercy  40.737210 -73.981376        9.300000
# 29       Brooklyn           Greenpoint  40.730201 -73.954241        9.400000
# 30      Manhattan    Greenwich Village  40.726933 -73.999914        9.300000
# 31      Manhattan     Hamilton Heights  40.823604 -73.949688        8.600000
# 32         Queens              Hammels  40.587338 -73.805530        8.500000
# 33          Bronx         High  Bridge  40.836623 -73.926102        8.500000
# 34       Brooklyn        Highland Park  40.681999 -73.890346        8.400000
# 35      Manhattan         Hudson Yards  40.756658 -74.000111        9.300000
# 36         Queens        Hunters Point  40.743414 -73.953868        9.400000
# 37       Brooklyn           Kensington  40.642382 -73.980421        8.900000
# 38      Manhattan           Lenox Hill  40.768113 -73.958860        9.200000
# 39      Manhattan         Little Italy  40.719324 -73.997305        9.300000
# 40         Queens          Little Neck  40.770826 -73.738898        8.400000
# 41         Queens     Long Island City  40.750217 -73.939202        9.400000
# 42          Bronx             Longwood  40.815099 -73.895788        8.700000
# 43      Manhattan      Lower East Side  40.717807 -73.980890        9.400000
# 44      Manhattan       Manhattanville  40.816934 -73.957385        8.900000
# 45          Bronx              Melrose  40.819754 -73.909422        8.666667
# 46      Manhattan        Midtown South  40.748510 -73.988713        9.300000
# 47       Brooklyn              Midwood  40.625596 -73.957595        8.900000
# 48          Bronx           Morrisania  40.823592 -73.901506        8.500000
# 49          Bronx           Mott Haven  40.806239 -73.916100        8.900000
# 50         Queens             Neponsit  40.572037 -73.857547        8.500000
# 51       Brooklyn             New Lots  40.662744 -73.885118        8.400000
# 52      Manhattan                 Noho  40.723259 -73.988434        9.300000
# 53       Brooklyn           North Side  40.714823 -73.958809        9.400000
# 54          Bronx          Port Morris  40.801664 -73.913221        8.900000
# 55       Brooklyn  Prospect Park South  40.647009 -73.962613        8.900000
# 56         Queens           Ravenswood  40.761705 -73.931575        9.100000
# 57       Brooklyn       Remsen Village  40.652117 -73.916653        8.400000
# 58         Queens       Rockaway Beach  40.582802 -73.822361        8.500000
# 59         Queens        Rockaway Park  40.580343 -73.841534        8.500000
# 60      Manhattan     Roosevelt Island  40.762160 -73.949168        9.200000
# 61         Queens              Roxbury  40.567376 -73.892138        8.500000
# 62      Manhattan                 Soho  40.722184 -74.000657        9.300000
# 63         Queens           Somerville  40.597711 -73.796648        8.500000
# 64       Brooklyn           South Side  40.710861 -73.958001        9.400000
# 65      Manhattan      Stuyvesant Town  40.731000 -73.974052        9.400000
# 66         Queens            Sunnyside  40.740176 -73.926916        9.400000
# 67  Staten Island            Sunnyside  40.612760 -74.097126        9.400000
# 68       Brooklyn          Sunset Park  40.645103 -74.010316        8.900000
# 69      Manhattan              Tribeca  40.721522 -74.010683        9.300000
# 70      Manhattan      Upper East Side  40.775639 -73.960508        9.100000
# 71       Brooklyn         Vinegar Hill  40.703321 -73.981116        9.400000
# 72      Manhattan         West Village  40.734434 -74.006180        9.300000
# 73       Brooklyn         Williamsburg  40.707144 -73.958115        9.400000
# 74      Manhattan            Yorkville  40.775930 -73.947118        9.100000

# %% [markdown]
# We will consider all the neighborhoods with average rating greater or equal 9.0 to visualize on map

# %%
ny_neighborhood_stats=ny_neighborhood_stats[ny_neighborhood_stats['Average Rating']>=9.0]
ny_neighborhood_stats
# Out:
#           Borough        Neighborhood   Latitude  Longitude  Average Rating
# 1       Manhattan   Battery Park City  40.711932 -74.016869            9.30
# 3          Queens          Blissville  40.737251 -73.932442            9.40
# 9        Brooklyn            Bushwick  40.698116 -73.925258            9.00
# 10      Manhattan       Carnegie Hill  40.782683 -73.953256            9.10
# 14      Manhattan           Chinatown  40.715618 -73.994279            9.30
# 16      Manhattan        Civic Center  40.715229 -74.005415            9.30
# 17      Manhattan             Clinton  40.759101 -73.996119            9.30
# 22      Manhattan        East Village  40.727847 -73.982226            9.35
# 23       Brooklyn   East Williamsburg  40.708492 -73.938858            9.40
# 25      Manhattan  Financial District  40.707107 -74.010665            9.30
# 27      Manhattan            Flatiron  40.739673 -73.990947            9.30
# 28      Manhattan            Gramercy  40.737210 -73.981376            9.30
# 29       Brooklyn          Greenpoint  40.730201 -73.954241            9.40
# 30      Manhattan   Greenwich Village  40.726933 -73.999914            9.30
# 35      Manhattan        Hudson Yards  40.756658 -74.000111            9.30
# 36         Queens       Hunters Point  40.743414 -73.953868            9.40
# 38      Manhattan          Lenox Hill  40.768113 -73.958860            9.20
# 39      Manhattan        Little Italy  40.719324 -73.997305            9.30
# 41         Queens    Long Island City  40.750217 -73.939202            9.40
# 43      Manhattan     Lower East Side  40.717807 -73.980890            9.40
# 46      Manhattan       Midtown South  40.748510 -73.988713            9.30
# 52      Manhattan                Noho  40.723259 -73.988434            9.30
# 53       Brooklyn          North Side  40.714823 -73.958809            9.40
# 56         Queens          Ravenswood  40.761705 -73.931575            9.10
# 60      Manhattan    Roosevelt Island  40.762160 -73.949168            9.20
# 62      Manhattan                Soho  40.722184 -74.000657            9.30
# 64       Brooklyn          South Side  40.710861 -73.958001            9.40
# 65      Manhattan     Stuyvesant Town  40.731000 -73.974052            9.40
# 66         Queens           Sunnyside  40.740176 -73.926916            9.40
# 67  Staten Island           Sunnyside  40.612760 -74.097126            9.40
# 69      Manhattan             Tribeca  40.721522 -74.010683            9.30
# 70      Manhattan     Upper East Side  40.775639 -73.960508            9.10
# 71       Brooklyn        Vinegar Hill  40.703321 -73.981116            9.40
# 72      Manhattan        West Village  40.734434 -74.006180            9.30
# 73       Brooklyn        Williamsburg  40.707144 -73.958115            9.40
# 74      Manhattan           Yorkville  40.775930 -73.947118            9.10

# %% [markdown]
# Now we can show this data on a map

# %%
# create map and display it
ny_map = folium.Map(location=geo_location('New York'), zoom_start=12)


# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in ny_neighborhood_stats[['Latitude','Longitude']].values:
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        )
    )

# %% [markdown]
# Lets add a new field to dataframe for labeling purpose

# %%
ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'
# Out:
# <ipython-input-52-dc22b1634a36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ny_neighborhood_stats['Label']=ny_neighborhood_stats['Neighborhood']+', '+ny_neighborhood_stats['Borough']+'('+ny_neighborhood_stats['Average Rating'].map(str)+')'

# %%
# add pop-up text to each marker on the map
for lat, lng, label in ny_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(ny_map)        
# add incidents to map
ny_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_3c0027159a304e3ea7b110236e7b9256%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3c0027159a304e3ea7b110236e7b9256%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3c0027159a304e3ea7b110236e7b9256%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_3c0027159a304e3ea7b110236e7b9256%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7127281%2C-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# # Results

# %% [markdown]
# This study on French restaurant in New-York show that the Borough with the better rated french restaurant are Manhattan follow by Brooklyn.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In New-york according to the data available on foursquare and Wekipedia regarding French restaurent the five neighborhood where we can find the bettre French restaurant are :
# - Hunters
# - Sunnyside
# - East Willamsburg
# - Long Island City
# - Lower East Side
#
# All rated 9,4 which constitue the highest rate.
# Manhattan is the best place to stay if you like French Cuisine and if you want to open a  trendy new French restaurant in New City
